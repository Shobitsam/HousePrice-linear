# %%
#importing important libraries 
import numpy as np     #for 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#reading the dataset 
df= pd.read_csv(r'C:\Users\ASUS\Desktop\data analysis\all_csv_file\housing_big.csv')

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
#inspacting the dataset 
df.shape    #total 1460 row and 81 columns
# Out:
# (1460, 81)

# %%
#checking the datatype (int, object, float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#checking null values in every columns 
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
#checking the null values in percantage form in every columns for better understanding 
round(df.isnull().sum()/len(df)* 100,0)
# Out:
# Id                0.0
# MSSubClass        0.0
# MSZoning          0.0
# LotFrontage      18.0
# LotArea           0.0
#                  ...
# MoSold            0.0
# YrSold            0.0
# SaleType          0.0
# SaleCondition     0.0
# SalePrice         0.0
# Length: 81, dtype: float64

# %%
#checking null values above 80 percantage by useing the  threshold
threshhold = 80
missing_percentage = (df.isnull().sum()/len(df))* 100
variable_above_treshold = missing_percentage[missing_percentage>threshhold]

# %%
variable_above_treshold
# Out:
# Alley          93.767123
# PoolQC         99.520548
# Fence          80.753425
# MiscFeature    96.301370
# dtype: float64

# %%
#drop the columns where the null vakues is above 80 percantage 
df.drop (['Alley','PoolQC','Fence','MiscFeature'],axis =1,inplace = True)

# %%
#after droping the columns inspacting the dataset 
df.shape
# Out:
# (1460, 77)

# %%
#again checking the null values above 1o percentage
threshold = 10 
missing_percentage = round(df.isnull().sum() / len(df) *100,0)
variable_above_threshold = missing_percentage [missing_percentage > threshold]

# %%
variable_above_threshold
# Out:
# LotFrontage    18.0
# MasVnrType     60.0
# FireplaceQu    47.0
# dtype: float64

# %%
#drop the columns where the null value above 10 percenatge 
df.drop(['LotFrontage','MasVnrType','FireplaceQu'],axis = 1,inplace = True)

# %%
df.shape
# Out:
# (1460, 74)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 74 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
# ...

# %%
#by using this code we can check which columns have object values  
df.select_dtypes (include = 'object')
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...      ...         ...       ...       ...       ...
# 1455       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2  ... Electrical KitchenQual  \
# ...

# %%
#by using this code we can create new data frame where we can store only the non-object values for better understanding 
df1= df.select_dtypes(exclude = 'object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 37 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   LotArea        1460 non-null   int64
#  3   OverallQual    1460 non-null   int64
#  4   OverallCond    1460 non-null   int64
#  5   YearBuilt      1460 non-null   int64
#  6   YearRemodAdd   1460 non-null   int64
#  7   MasVnrArea     1452 non-null   float64
#  8   BsmtFinSF1     1460 non-null   int64
#  9   BsmtFinSF2     1460 non-null   int64
#  10  BsmtUnfSF      1460 non-null   int64
#  11  TotalBsmtSF    1460 non-null   int64
#  12  1stFlrSF       1460 non-null   int64
#  13  2ndFlrSF       1460 non-null   int64
#  14  LowQualFinSF   1460 non-null   int64
#  15  GrLivArea      1460 non-null   int64
#  16  BsmtFullBath   1460 non-null   int64
#  17  BsmtHalfBath   1460 non-null   int64
# ...

# %%
# 1st i create this heatmap by using this code and then check the highly correlation between ('salesprice' and other valriables)above 50 percent 
corr = df1.corr()
plt.figure(figsize = (30,20))
sns.heatmap(corr,annot = True,cmap = 'YlGnBu')
plt.title('Correlation Matrix Heatmap')   #giving title for heatmap 
plt.show()     #for show heatmap
# Out:
# <Axes: >

# %%
#when i find highly correlated variables then i add these var in new dataset for future prediction 
df1 = df[["SalePrice","OverallQual","GrLivArea","GarageCars","GarageArea","TotalBsmtSF","1stFlrSF"]]

# %%
df1
# Out:
#       SalePrice  OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  \
# 0        208500            7       1710           2         548          856
# 1        181500            6       1262           2         460         1262
# 2        223500            7       1786           2         608          920
# 3        140000            7       1717           3         642          756
# 4        250000            8       2198           3         836         1145
# ...         ...          ...        ...         ...         ...          ...
# 1455     175000            6       1647           2         460          953
# 1456     210000            6       2073           2         500         1542
# 1457     266500            7       2340           1         252         1152
# 1458     142125            5       1078           1         240         1078
# 1459     147500            5       1256           1         276         1256
#
#       1stFlrSF
# 0          856
# ...

# %%
df1.isnull().sum()
# Out:
# SalePrice      0
# OverallQual    0
# GrLivArea      0
# GarageCars     0
# GarageArea     0
# TotalBsmtSF    0
# 1stFlrSF       0
# dtype: int64

# %%
#i create X var  and drop saleprice columns  and call rest columns in X var 
X = df1.drop(['SalePrice'],axis = 1)

# %%
X.head()       #calling X var by using head method only 5 rows
# Out:
#    OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  1stFlrSF
# 0            7       1710           2         548          856       856
# 1            6       1262           2         460         1262      1262
# 2            7       1786           2         608          920       920
# 3            7       1717           3         642          756       961
# 4            8       2198           3         836         1145      1145

# %%
#i create y var and add only saleprice in y var 
y = df1['SalePrice']

# %%
y    # call y var
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
#import train test split for spliting training and  testing data  
from sklearn.model_selection import train_test_split

# %%
train_test_split?

# %%
# Split the data: 80% for training and 20% for testing
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# %%
X_train      #calling Xtrain
# Out:
#       OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  1stFlrSF
# 133             8       1296           2         471         1267      1296
# 290             8       1919           2         685         1079      1079
# 24              5       1060           1         270         1060      1060
# 1093            5       1200           2         884          864      1200
# 1288            8       1659           2         499         1501      1659
# ...           ...        ...         ...         ...          ...       ...
# 802             7       1456           2         410          728       728
# 53              9       1842           3         894         1842      1842
# 350             9       1869           2         617         1869      1869
# 79              5       1230           2         440          440       682
# 792             7       2013           2         455         1117      1127
#
# [1168 rows x 6 columns]

# %%
X_test   #calling X test
# Out:
#       OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  1stFlrSF
# 1436            4        864           2         528          864       864
# 57              7       1720           2         565          860       860
# 780             7       1253           2         402         1237      1253
# 382             7       1797           2         639          939       939
# 1170            6       1118           1         358         1096      1118
# ...           ...        ...         ...         ...          ...       ...
# 1328            6       2792           2         520         1510      1584
# 1033            7       1654           3         900         1654      1654
# 977             7       1241           2         569         1241      1241
# 661             8       2448           3         711         1629      1686
# 914             6       1224           2         528          612       612
#
# [292 rows x 6 columns]

# %%
y_train         #calling y train
# Out:
# 133     220000
# 290     233230
# 24      154000
# 1093    146000
# 1288    278000
#          ...
# 802     189000
# 53      385000
# 350     318061
# 79      110000
# 792     269790
# Name: SalePrice, Length: 1168, dtype: int64

# %%
y_train           #calling y train
# Out:
# 133     220000
# 290     233230
# 24      154000
# 1093    146000
# 1288    278000
#          ...
# 802     189000
# 53      385000
# 350     318061
# 79      110000
# 792     269790
# Name: SalePrice, Length: 1168, dtype: int64

# %%
#by using sklearn linear model import linear regression 
from sklearn.linear_model import LinearRegression

# %%
# assign linear regression in lv var for better understanding 
lv = LinearRegression()

# %%
#by using this code fitting X traning data and y traning data 
lv.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# after fitting the model testing the X test  
y_pred = lv.predict (X_test)

# %% [raw]
# y_pred

# %%
#caling  r2 score by sklearn matris for r2 score 
from sklearn.metrics import r2_score

# %%
#after model prediction i can test my my r2 score by adding y test 
r2= r2_score (y_test,y_pred)

# %%
print (r2)
# Out:
# 0.8129353540646322
